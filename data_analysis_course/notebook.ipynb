# %%
import pandas as pd

df = pd.read_csv("data/credits.csv", delimiter=',')
df.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
import pandas as pd

orai = {
'data': ['7/1/2019', '7/2/2019', '7/3/2019','7/4/2019','7/5/2019'], 
'temperatura': [32, 35, 28, 24, 22], 
'vejas': [6,7,2,4,5],
'oras': ['Lietus', 'Saulėta','Saulėta','Saulėta','Debesuota']
}
df = pd.DataFrame(orai)
df
# Out:
#        data  temperatura  vejas       oras
# 0  7/1/2019           32      6     Lietus
# 1  7/2/2019           35      7    Saulėta
# 2  7/3/2019           28      2    Saulėta
# 3  7/4/2019           24      4    Saulėta
# 4  7/5/2019           22      5  Debesuota

# %%
df["temperatura"].max()
# Out:
# 35

# %%
df["temperatura"].mean()
# Out:
# 28.2

# %%
print(df.shape)
# Out:
# (77213, 5)

# %%
df.head()
# Out:
#    person_id       id             name                character   role
# 0       3748  tm84618   Robert De Niro            Travis Bickle  ACTOR
# 1      14658  tm84618     Jodie Foster            Iris Steensma  ACTOR
# 2       7064  tm84618    Albert Brooks                      Tom  ACTOR
# 3       3739  tm84618    Harvey Keitel  Matthew 'Sport' Higgins  ACTOR
# 4      48933  tm84618  Cybill Shepherd                    Betsy  ACTOR

# %%
df2 = df[0:3]

# %%
df2.head()
# Out:
#    person_id       id            name      character   role
# 0       3748  tm84618  Robert De Niro  Travis Bickle  ACTOR
# 1      14658  tm84618    Jodie Foster  Iris Steensma  ACTOR
# 2       7064  tm84618   Albert Brooks            Tom  ACTOR

# %%
df.iloc[2, 2] #galima pasiimti rows & colum reiksmes(pirmas skaiciu rows, antras columm)
# Out:
# 'Albert Brooks'

# %%
df
# Out:
#        person_id         id                    name                character  \
# 0           3748    tm84618          Robert De Niro            Travis Bickle
# 1          14658    tm84618            Jodie Foster            Iris Steensma
# 2           7064    tm84618           Albert Brooks                      Tom
# 3           3739    tm84618           Harvey Keitel  Matthew 'Sport' Higgins
# 4          48933    tm84618         Cybill Shepherd                    Betsy
# ...          ...        ...                     ...                      ...
# 77208    1347054  tm1098060  Nnenna Rachael Okonkwo                   Afinni
# 77209     157590  tm1098060           Lucien Morgan           Dr. Ian Stones
# 77210     129059  tm1098060        Magdalena Korpas                     Jane
# 77211    2050199  tm1098060        Mistura Olusanya               Nurse Titi
# 77212    2050423  tm1098060              Yemi Amodu                      NaN
#
#            role
# 0         ACTOR
# ...

# %%
df.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
for column in df.columns:
    print(column)
# Out:
# person_id
# id
# name
# character
# role

# %%
df[["person_id", 'name']]
# Out:
#        person_id                    name
# 0           3748          Robert De Niro
# 1          14658            Jodie Foster
# 2           7064           Albert Brooks
# 3           3739           Harvey Keitel
# 4          48933         Cybill Shepherd
# ...          ...                     ...
# 77208    1347054  Nnenna Rachael Okonkwo
# 77209     157590           Lucien Morgan
# 77210     129059        Magdalena Korpas
# 77211    2050199        Mistura Olusanya
# 77212    2050423              Yemi Amodu
#
# [77213 rows x 2 columns]

# %%
df.loc[df['person_id'] < 3739]
# Out:
#        person_id              name
# 9           3308   Martin Scorsese
# 36          3308   Martin Scorsese
# 38          1549       John Cleese
# 86          1549       John Cleese
# 107         1700     Ellen Burstyn
# ...          ...               ...
# 76468       1027   Erin Fitzgerald
# 76546        439       Sam Vincent
# 76696        202          Roy Chiu
# 77096       1350     Parmeet Sethi
# 77159        497  Jolina Magdangal
#
# [3548 rows x 2 columns]

# %%
df.loc[df['name'].str.contains("John")]
# Out:
#        person_id                   name
# 38          1549            John Cleese
# 47         11481             John Young
# 54        589811          Sandy Johnson
# 81          8327          John Thornton
# 86          1549            John Cleese
# ...          ...                    ...
# 76045    1855942              Jipa John
# 76501     109159         John Tartaglia
# 76716    2009096               Johnmans
# 76933      66826           John Abraham
# 77203     530811  Toyin Aimakhu-Johnson
#
# [1052 rows x 2 columns]

# %%
df.sort_values('name', ascending=False)
# Out:
#        person_id                 name
# 25160    2000678                  허윤무
# 63519    1989175                   지뢰
# 62024    1978797                  주둥닝
# 63536    2201544                  조경이
# 25158    2000667                  정봉주
# ...          ...                  ...
# 62576    1104066            21 Savage
# 37701       6246  'Weird Al' Yankovic
# 67543       6246  'Weird Al' Yankovic
# 59340     209364         'Jeeva' Ravi
# 19791     600028       Michael Hayden
#
# [77213 rows x 2 columns]

# %%
import pandas as pd

df = pd.read_csv("data/titles.csv", delimiter=',')
df.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm127384      Monty Python and the Holy Grail  MOVIE
# 3   tm70993                        Life of Brian  MOVIE
# 4  tm190788                         The Exorcist  MOVIE
# 5   ts22164         Monty Python's Flying Circus   SHOW
# 6   tm14873                          Dirty Harry  MOVIE
# 7  tm185072                         My Fair Lady  MOVIE
# 8   tm98978                      The Blue Lagoon  MOVIE
# 9  tm119281                     Bonnie and Clyde  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  King Arthur, accompanied by his squire, recrui...          1975
# 3  Brian Cohen is an average young Jewish man, bu...          1979
# ...

# %%
df.groupby(['title']).mean().sort_values('imdb_score', ascending=False)
# Out:
#                    release_year  runtime  seasons  imdb_score  imdb_votes  \
# title
# #ABtalks                 2018.0     68.0      1.0         9.6         7.0
# Khawatir                 2005.0     20.0     11.0         9.6      3046.0
# Breaking Bad             2008.0     48.0      5.0         9.5   1727694.0
# Our Planet               2019.0     50.0      1.0         9.3     41386.0
# Kota Factory             2019.0     42.0      2.0         9.3     66985.0
# ...                         ...      ...      ...         ...         ...
# นางสาวก้นครัว            2019.0     48.0      1.0         NaN         NaN
# ปริศนาล่าข้ามเวลา        2019.0     62.0      1.0         NaN         NaN
# 幸福料理                     2014.0     44.0      1.0         NaN         NaN
# 마법버스 타요                  2020.0     24.0      1.0         NaN         NaN
# 캐치! 티니핑                  2020.0     12.0      2.0         NaN         NaN
#
#                    tmdb_popularity  tmdb_score
# title
# ...
